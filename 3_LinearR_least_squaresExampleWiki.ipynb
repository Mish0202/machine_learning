# %%
import numpy as np

# %%
y= np.array( [[6], [5], [7], [10]])
X= np.array([[1, 1], [1, 2], [1, 3], [1, 4]])

# %%
y, y.shape, X, X.shape
# Out:
# (array([[ 6],
#         [ 5],
#         [ 7],
#         [10]]),
#  (4, 1),
#  array([[1, 1],
#         [1, 2],
#         [1, 3],
#         [1, 4]]),
#  (4, 2))

# %%
X_T = np.transpose(X)

# %%
X_T, X_T.shape
# Out:
# (array([[1, 1, 1, 1],
#         [1, 2, 3, 4]]),
#  (2, 4))

# %%
X_TmultX = np.matmul(X_T, X)

# %%
X_TmultX, X_TmultX.shape
# Out:
# (array([[ 4, 10],
#         [10, 30]]),
#  (2, 2))

# %%
np.linalg.det(X_TmultX)
# Out:
# 20.000000000000007

# %%
X_Tmult_y = np.matmul(X_T, y)

# %%
from numpy.linalg import inv

# %%
X_Tmult_Xinv = inv(X_TmultX)

# %%
beta = np.matmul(X_Tmult_Xinv, X_Tmult_y)
beta
# Out:
# array([[3.5],
#        [1.4]])

# %% [markdown]
# Ниже расчет вручную по тем же данным

# %% [markdown]
# ![1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![3.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![4.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![5.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Ниже расчет по тем же данным через статистическую формулу и с таблицей в экселе.

# %% [markdown]
# ![Screenshot 2024-07-14 at 12.45.47 (2).png](data:image/png;base64,...)
